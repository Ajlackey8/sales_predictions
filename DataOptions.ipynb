# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajlackey8/sales_predictions/blob/main/DataOptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_games = pd.read_csv('/content/Video_Games_Sales_as_at_22_Dec_2016.csv')
df_games.head()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# 1.) Source is Kaggle
#
# 2.) Data is cataloging various information about videogames associated with their sales and critical scores.
#
# 3.) The target in this case would likely be sales trends in the gaming industry to help predict the next big thing$
#
# 4.) regression, predicting sales is not discrete categories, instead it is any number on a numerical sales scale
#
# 5.) after dropping Name and removing all sales but global, we would have 10 features
#
# 6.) 16719 rows
#
# 7.) this dataset has a lot of missing data in the critical and user ratings as smaller games haven't really gotten them. With reviews being I'm guessing a fairly strong indicator of quality missing a lot of them may cause problems. However, I'm guessing if you don't even have metacritic reviews your sales probably were pretty bad anyway so that might be it's own category.

# %%
df_homicide = pd.read_csv('/content/database.csv')
df_homicide.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type  ... Victim Ethnicity  \
# 0  1980  January         1  Murder or Manslaughter  ...          Unknown
# 1  1980    March         1  Murder or Manslaughter  ...          Unknown
# 2  1980    March         2  Murder or Manslaughter  ...          Unknown
# ...

# %% [markdown]
# 1.) Source is Kaggle again
#
# 2.) Homicide data from FOIA requests on the FBI mostly.
#
# 3.) The target could vary depending on what we want out of the database. But considering things like gun laws are a hot topic now, it might be interesting to train a database to be able to predict weapons most likely used in crimes and see if it has any meaningful correlation with states having more or less strict gun laws.
#
# 4.) classification
#
# 5.) 22 (with record Id removed)
#
# 6.) 638454
#
# 7.) There are a lot of potential issues here, between missing/unknown data. The political sensitivity of the topic (especially since it will be using race as a feature in a crime prediction model, yikes) and the fact that to make meaningful conclusions on crime/weapon usage we would need to bring in external data on gun laws.
